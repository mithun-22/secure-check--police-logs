# %% [markdown]
# <a href="https://colab.research.google.com/github/mithun-22/secure-check--police-logs/blob/main/securecheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
traffic = pd.read_csv("/content/traffic_new.csv")
traffic.head()
# Out:
# <ipython-input-3-884f0ba82d4d>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   traffic = pd.read_csv("/content/traffic_new.csv")
#     stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0  2020-01-01   0:00:00       Canada             M              59
# 1  2020-01-01   0:01:00        India             M              35
# 2  2020-01-01   0:02:00          USA             M              26
# 3  2020-01-01   0:03:00       Canada             M              26
# 4  2020-01-01   0:04:00       Canada             M              62
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0          19       Asian     Drunk Driving  Speeding              True
# 1          58       Other             Other     Other             False
# 2          76       Black  Signal Violation  Speeding             False
# 3          76       Black          Speeding       DUI              True
# ...

# %%
import streamlit as st
from datetime import datetime

# %%
@st.cache_data
def load_data():
    return pd.read_csv("/content/traffic_new.csv")

data = load_data()
# Out:
# 2025-04-24 15:28:08.204 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-04-24 15:28:08.207 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-04-24 15:28:08.208 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 15:28:08.314
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-04-24 15:28:08.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 15:28:08.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <ipython-input-14-18d2fd19a7fa>:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
# %%writefile app.py
import streamlit as st
from datetime import datetime

st.title("🚔New Police Log & Predict Outcome and Violation")

# --- Input Fields ---
stop_date = st.date_input("Stop Date")
stop_time = st.time_input("Stop Time")
county_name = st.text_input("County Name")
driver_gender = st.selectbox("Driver Gender", ["male", "female", "other"])
driver_age = st.number_input("Driver Age", min_value=0, max_value=120, step=1)
driver_race = st.text_input("Driver Race")
search_conducted = st.selectbox("Was a Search Conducted?", ["0", "1"])
search_type = st.text_input("Search Type")
drug_related = st.selectbox("Was it Drug Related?", ["0", "1"])
stop_duration = st.selectbox("Stop Duration", ["0-15 Min", "16-30 Min", "30+ Min"])
vehicle_number = st.text_input("Vehicle Number")

# --- Predict Button ---
if st.button("Predict Stop Outcome & Violation"):
    # Simulate Prediction Output (Replace this with model prediction logic)
    predicted_outcome = "Warning"     # e.g., Warning, Citation, Arrest
    predicted_violation = "Speeding"  # e.g., Speeding, Registration, Seat belt, etc.

    # --- Display Output ---
    st.subheader("📋 Prediction Result")
    st.markdown(f"**Predicted Outcome:** {predicted_outcome}")
    st.markdown(f"**Predicted Violation:** {predicted_violation}")
# Out:
# Overwriting app.py

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# added 22 packages in 3s
# ⠇
# ⠇3 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 78.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# !streamlit run /content/app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.136.6.248
# ⠙your url is: https://mighty-moons-post.loca.lt
